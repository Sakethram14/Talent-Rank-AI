# %% [markdown]
# # TalentRank AI: Company and Title Analysis

# %%
import pandas as pd
import sys
sys.path.insert(0, '../')
from src.utils.io import load_jsonl
from src.config.settings import get_settings

candidates = list(load_jsonl(get_settings().paths.candidates_jsonl, max_records=10000))
